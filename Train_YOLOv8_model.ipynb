# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_path = "/content/drive/MyDrive/Food recognition/Food_detection_and_health_care.v2i.yolov8.zip"
output_path = "/content/dataset"

# Unzip the dataset
# !unzip -q "$zip_path" -d "$output_path"

# %%
# Check dataset structure
# !ls "$output_path"
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.3/896.3 kB 23.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8s.pt")

# Train the model
model.train(
    data="/content/dataset/data.yaml",  # Path to the YAML file
    epochs=70,  # Number of epochs
    imgsz=640,  # Image size
    project="/content/yolo_project",  # Folder to save results
    name="food_detection" # Model name
)
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
import os

# Create a folder in Google Drive to save the model
save_dir = "/content/drive/MyDrive/yolo_models"
os.makedirs(save_dir, exist_ok=True)

# Copy the best model (best.pt) to Google Drive
source_path = "/content/yolo_project/food_detection2/weights/best.pt"
destination_path = os.path.join(save_dir, "food_detection_best.pt")
shutil.copy(source_path, destination_path)

# Copy the last model (last.pt) to Google Drive
source_path_last = "/content/yolo_project/food_detection2/weights/last.pt"
destination_path_last = os.path.join(save_dir, "food_detection_last.pt")
shutil.copy(source_path_last, destination_path_last)

print(f"Model đã được lưu tại:\n- {destination_path}\n- {destination_path_last}")
# Out:
# Model đã được lưu tại:
# - /content/drive/MyDrive/yolo_models/food_detection_best.pt
# - /content/drive/MyDrive/yolo_models/food_detection_last.pt

# %%
from ultralytics import YOLO

# Load the model from Google Drive
model_path = "/content/drive/MyDrive/yolo_models/food_detection_best.pt"
model = YOLO(model_path)

# %%
import matplotlib.pyplot as plt

# Perform predictions on an image
results = model.predict(
    source='https://img-global.cpcdn.com/recipes/2c630c584ca9709c/680x482cq70/bun-d%E1%BA%ADu-m%E1%BA%AFm-tom-recipe-main-photo.jpg',
    conf=0.5  # Confidence threshold
)

# Get the image with bounding boxes annotated
annotated_image = results[0].plot()

# Display the image in Google Colab
plt.imshow(annotated_image)
plt.axis('off')  # Turn off axis display
plt.show()
# Out:
# ...
# 100%|██████████| 76.1k/76.1k [00:00<00:00, 7.57MB/s]
# image 1/1 /content/bun-dậu-mắm-tom-recipe-main-photo.jpg: 480x640 1 bun, 1 bun dau, 1 cha com, 5 dau hus, 2 thit heos, 146.9ms
# Speed: 5.4ms preprocess, 146.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Perform predictions on an image
results = model.predict(
    source='https://i2.ex-cdn.com/crystalbay.com/files/content/2024/08/15/bun-bo-hue-2-0933.jpg',
    conf=0.5  # Confidence threshold
)

# Get the image with bounding boxes annotated
annotated_image = results[0].plot()

# Display the image in Google Colab
plt.imshow(annotated_image)
plt.axis('off')  # Turn off axis display
plt.show()
# Out:
# ...
# 100%|██████████| 379k/379k [00:00<00:00, 20.8MB/s]
# image 1/1 /content/bun-bo-hue-2-0933.jpg: 448x640 1 bun, 1 bun bo, 376.9ms
# Speed: 4.3ms preprocess, 376.9ms inference, 16.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Perform predictions on an image
results = model.predict(
    source='https://static.hawonkoo.vn/hwk02/images/2023/10/com-tam-suon-bi-cha-2.jpg',
    conf=0.5  # Confidence threshold
)

# Get the image with bounding boxes annotated
annotated_image = results[0].plot()

# Display the image in Google Colab
plt.imshow(annotated_image)
plt.axis('off')  # Turn off axis display
plt.show()
# Out:
# ...
# 100%|██████████| 767k/767k [00:00<00:00, 924kB/s]
# image 1/1 /content/com-tam-suon-bi-cha-2.jpg: 384x640 1 bi, 1 cha, 1 com, 1 com suon bi cha trung, 1 thit heo, 1 trung, 45.0ms
# Speed: 2.5ms preprocess, 45.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Get the list of classes
class_names = model.names
print("List of classes in the YOLO model:")
for i, name in class_names.items():
    print(f"{i}: {name}")
# Out:
# Danh sách các class trong mô hình YOLO:
# 0: banh da
# 1: banh gao
# 2: banh gao cay tokbokki
# 3: banh hoi
# 4: banh hoi heo quay
# 5: banh hu tieu
# 6: banh mi sandwish
# 7: banh pho
# 8: bap
# 9: bi
# 10: bun
# 11: bun bo
# 12: bun ca
# 13: bun dau
# 14: bun hai san
# 15: bun moc
# 16: ca
# 17: ca hoi
# 18: ca hoi sot pho mai kem
# 19: cac loai rau cu
# 20: cha
# 21: cha ca
# 22: cha com
# 23: cha gio
# 24: com
# 25: com ca ri
# 26: com chien cai xoan
# 27: com ga
# 28: com suon
# 29: com suon bi cha
# 30: com suon bi cha trung
# 31: com suon bi trung
# 32: com suon cha
# 33: com suon trung
# 34: dau hu
# 35: doi sun
# 36: dua chua
# 37: ga ran va khoai tay chien
# 38: gan
# 39: hu tieu
# 40: hu tieu mi
# 41: khoai tay chien
# 42: mi
# 43: mi ga hung que kem
# 44: mi jajangmyeon
# 45: mi misoramen
# 46: mi nuoc sup bun bo
# 47: mi quang
# 48: mi tron
# 49: mi tuong den Jajangmyeon
# 50: muc
# 51: naruto
# 52: pho bo
# 53: pho ga
# 54: pho mai
# 55: rau ram
# 56: soi mi khoai lang
# ...
